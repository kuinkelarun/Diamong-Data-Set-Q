# %% [markdown]
# <h1> Quiz Assignment </h1>

# %% [markdown]
# <h3> Part 1: Data Summary </h3>

# %% [markdown]
# <h3> Use cases: </h3>
#
# Use cases attempt to describe what a user tries to achieve by analyzing the given data sets. They provide the context for the interpretation of data to make business and other decisions.
#
# The given data set provides following few use cases, which helps in the decision-making process:
#
# Different attributes use different use cases, following are the few:
# - Cuts: Fair, Good, Very Good, Premium, Ideal are different use cases for cut
# - Color: D-J are different use cases for color, D-f are also the mostly available color for diamonds in the market, even though the range goes to Z starting from D

# %% [markdown]
# <h3> Attributes: </h3>
#
# The attributes provide the framework in which the data are analyzed. These attributes in some cases are the limitations in which the given data can be interpreted.
#
# Attributes in diamonds data sets are the carat, cut, color, clarity, depth, table, price, x, y, and z. We may interpret the data based on these attributes. But if we were to ask a question, if the place of origin of the diamond impact the price of the diamond, we do not have basis to interpret this question. In that sense, attributes are the parameters in which we can interpret our data.
#
# Following are a brief explanation of the attributes in the "diamonds" data, the range of values are based on "diamonds" data:
# - *carat* - Weight of the diamonds, (with min 0.2 - max 5.01)
#
# - > According to Tiffany & Co., "A diamond may have a higher carat weight without appearing larger and two diamonds of the same carat weight can vary in size if one is cut deeper than the other. In other words, it is important to note that carat weight does not necessarily denote size."
#
# - *depth* - Top to bottom measurement of diamond, height from the cutlet to the table (with min 43.00 - max 79.00, measured usually in millimeters)
#
# - *table* - The flat facet of the diamond, it is relative to the width of the diamond (with min 43.00 - max 95.00)
#
# - *price* - Price of diamond per carat in US dollars (with min $326 - max $18,823)
#
# It is important to note the following fact when it comes to the value of a diamond.
#
# - > The website tiffany.com says that "Taken by itself, carat weight does not determine a diamond’s value. For example, two one-carat stones can vary widely in price when clarity, color and cut are taken into consideration."
# - *color* - Our dataset has color ranging D - J. In general, diamond color ranges from D - Z, D-F being Colorless (best quality), G-J being Near Colorless (best value, as they look white like D-F when faced up), K-Z Faint Light Color (normally not sold in market, but they are available)
#
# - *cut* - Cuts ranges from Fair, Good, Very Good, Premium, Ideal. Cut of the diamonds determine the quality of a diamond, as it determines how much light the stone reflects. For example, a D-color diamond with, high carat and clarity with not so good cut may result a diamond being dull
#
# - *clarity* - It is a measurement of how clear the diamond is, which ranges from the best IF - worst l1.
#     - IF - Internally Flawless
#     - VVS1 & VVS2 - Very Slightly Included
#     - VS1 & VS2- Very Very Slightly Included
#     - SI1 & SI2 - Slightly Included
#     - I1 & I2 - Imperfect
#     - x - length in mm
#     - y - width in mm
#     - z - depth in mm
#
# Clarity being one among "four C's", a diamond industry term that directly impacts the price of a diamond.
# - >According to Tiffany & Co., "A diamond with a poor clarity grade has multiple inclusions, which directly affects sparkle. Because inclusions hinder the refraction and return of light, the lower the clarity grade, the cloudier the diamond will appear."

# %% [markdown]
# <h4>Diamond clarity chart included in the next box. </h4>

# %%
# %matplotlib inline 
from IPython.display import Image
Image('E:\Arun\Queens College\DataAnalytics\VS_Code\DiamondClarity.png')

# %% [markdown]
# In the following box, the data is being uploaded to pandas. The "df.head()" displays the data in a table, where 10 different attributes are visible as headings. These attributes are previously discussed in the "Attribute" section.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# import missingno as msno

df = pd.read_csv("https://raw.githubusercontent.com/kuinkelarun/Quiz_Assignment/main/diamonds.csv")

df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %% [markdown]
# Following code and the table generated by the code "df.describe()" provides us with the most general understanding of the data in hand.
#
# Following facts can be generated solely based on on the following table.
# - There are 53940 rows
# - Mean price of the diamonds is $3932.80, with the cheapest being $326.00 and the most expensive being $18,823.00
# - Minimum values of x, y and z are zero. We will further look into them to see what impacted their values to be zero in the next section
# - We do not observe any non negative values

# %%
df.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %% [markdown]
# We will re-examine the findings of the general understanding of the data and their co-relations in the EDA section. We will further explore different attributes of the data in more detail in the next part.

# %% [markdown]
# <h3> Part 2: Exploratory Data Analysis (EDA) </h3>

# %% [markdown]
# EDA deals with analyzing a data set for the purpose of summarixing its characterstics, identifying relationships between its attributes, and discovering patterns, trends, outliers, missing values and invalid values within the data.

# %% [markdown]
# In this section, we can expect to see the summary of statistics for each of the attributes. Graphical analysis for the attributes using Matplotlib and Seaborn library. Discriptions of my EDA findings along with Python code and histogram anywhere necesary.

# %% [markdown]
# However, I could like to find out the outliers in each attribute if there exists any before proceeding with the statistical summary.

# %% [markdown]
# <h4>Finding outliers, Check for Nulls, Missing Data, Unique Values, etc.: </h4>

# %% [markdown]
# <h4>Handling Zeroes: </h4>

# %% [markdown]
# The data that we have is fairly clean, however there are some missing values in the x, y and z attributes. Let us examine them, find out any inconsistency and handle them accordingly.

# %%
# locating the places where the value of x is zero
df_original = df

df.loc[df['x']==0]
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price    x  \
# 11182       11183   1.07      Ideal     F     SI2   61.6   56.0   4954  0.0
# 11963       11964   1.00  Very Good     H     VS2   63.3   53.0   5139  0.0
# 15951       15952   1.14       Fair     G     VS1   57.5   67.0   6381  0.0
# 24520       24521   1.56      Ideal     G     VS2   62.2   54.0  12800  0.0
# 26243       26244   1.20    Premium     D    VVS1   62.1   59.0  15686  0.0
# 27429       27430   2.25    Premium     H     SI2   62.8   59.0  18034  0.0
# 49556       49557   0.71       Good     F     SI2   64.1   60.0   2130  0.0
# 49557       49558   0.71       Good     F     SI2   64.1   60.0   2130  0.0
#
#           y    z
# 11182  6.62  0.0
# 11963  0.00  0.0
# 15951  0.00  0.0
# 24520  0.00  0.0
# 26243  0.00  0.0
# 27429  0.00  0.0
# 49556  0.00  0.0
# 49557  0.00  0.0

# %% [markdown]
# We can see that most of the y and z also have zero values, where the values of x are zeroes. In that case we can either replace all the values with the median value of the respective attribute or we can simply remove those rows where x, y and z have zero values.

# %%
# removind the row that contain y = 0, because if we 
# remove the rows with x = 0, we will also loose y, which has data value

df = df.loc[~(df['y'] == 0)]

# %%
# checking again to make sure that x = 0 are removed. 
# And we can see that there is still one x = 0 in row 11182

df.loc[df['x']==0]
# Out:
#        Unnamed: 0  carat    cut color clarity  depth  table  price    x     y  \
# 11182       11183   1.07  Ideal     F     SI2   61.6   56.0   4954  0.0  6.62
#
#          z
# 11182  0.0

# %%
# this shows that there are no more y = 0 values in our data set

df.loc[df['y']==0]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, carat, cut, color, clarity, depth, table, price, x, y, z]
# Index: []

# %% [markdown]
# Using imputation method, we can impute the values of x and z with respective median values, as they are numerical data.

# %%
# replace x with median value
df.loc[11182, 'x'] = df['x'].median()

# %%
# replace z with median value
df.loc[11182, 'z'] = df['z'].median()

# %%
# again check to see if there are any zero values in x
df.loc[df['x']==0]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, carat, cut, color, clarity, depth, table, price, x, y, z]
# Index: []

# %% [markdown]
# <h4>Checking Outliers: </h4>

# %%
# checking outliers on price, take the higher end 
# price and see if there are enough of the similar prices

df.loc[(df['price']>15000)]
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 25885       25886   1.54    Premium     E     VS2   62.3   58.0  15002  7.31
# 25886       25887   1.19      Ideal     F    VVS1   61.5   55.0  15005  6.82
# 25887       25888   2.10    Premium     I     SI1   61.5   57.0  15007  8.25
# 25888       25889   1.69      Ideal     D     SI1   60.8   57.0  15011  7.69
# 25889       25890   1.50  Very Good     G    VVS2   62.9   56.0  15013  7.22
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 27745       27746   2.00  Very Good     H     SI1   62.8   57.0  18803  7.95
# 27746       27747   2.07      Ideal     G     SI2   62.5   55.0  18804  8.20
# 27747       27748   1.51      Ideal     G      IF   61.7   55.0  18806  7.37
# 27748       27749   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90
# 27749       27750   2.29    Premium     I     VS2   60.8   60.0  18823  8.50
#
#           y     z
# 25885  7.39  4.58
# ...

# %% [markdown]
# The prices higher than $15,000 seems reasonable as there are 1653 rows with such amount. It makes the maximum price reasonable.

# %% [markdown]
# The mean of "depth" and "table" and "x"are fairly reasonable when you look at the min and the max value. So let us examin for x and y.

# %% [markdown]
# Because the gap between the max value and mean of "y" is very high, let us examine if there are any outliers there.

# %%
df.loc[(df['y']>15)]
# Out:
#        Unnamed: 0  carat      cut color clarity  depth  table  price     x  \
# 24067       24068   2.00  Premium     H     SI2   58.9   57.0  12210  8.09
# 49189       49190   0.51    Ideal     E     VS1   61.8   55.0   2075  5.15
#
#           y     z
# 24067  58.9  8.06
# 49189  31.8  5.12

# %% [markdown]
# It appears that there are only two values that are greater than 15 among 53940 rows in total, which shows that the data is entered wrong on those fields. It is better to take off those two rows.

# %%
# remove 2 rows that contain values higher than 15

df.loc[~(df['y'] > 15)]
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
# checking the outlier for z, the value that is very high than the rest of the data

df.loc[(df['z'] > 15)]
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 48410       48411   0.51  Very Good     E     VS1   61.8   54.7   1970  5.12
#
#           y     z
# 48410  5.15  31.8

# %%
# remove that 1 row containing outlier value

df.loc[~(df['z']>15)]
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
# checking for any "?"

df.loc[df['x']=='?']
df.loc[df['y']=='?']
df.loc[df['z']=='?']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, carat, cut, color, clarity, depth, table, price, x, y, z]
# Index: []

# %% [markdown]
# The data is fairly clean at this point. We can move on to do the statistical analysis now.

# %% [markdown]
# <h4> Mooving on with EDA After Some Data Cleaning </h4>

# %% [markdown]
# <h4> We will be using bar plot for categorical data, and box plot or histogram for numerical data.</h4>

# %% [markdown]
# - > <h4>Using histogram from Matplotlib and Seaborn library to provide graphical representation of numerical data such as carat, depth, table, price, x, y and z as follows:</h4>

# %% [markdown]
# <h3>Carat:</h3>

# %%
#checking data types
df['carat'].dtype
# Out:
# dtype('float64')

# %%
# Using Matplotlib Histogram 
df['carat'].hist()
# Out:
# <AxesSubplot:>

# %%
# Using Seaborn Histogram 

sns.histplot(data=df, x="carat")
plt.show()

# %% [markdown]
# Diamonds with or around 0.4 carat are sold the most in quantity. Higher carat meaning heigher density of the diamond. Higher carat diamonds are sold less than lower carat ones. Both of these histogram are relatively similar in structure, which gives more confidence in the finding.

# %% [markdown]
# <h3> Depth: </h3>

# %%
# Using Matplotlib Histogram 

df['depth'].hist()
# Out:
# <AxesSubplot:>

# %%
# Using Seaborn Histogram 

sns.histplot(data=df, x="depth")
plt.show()

# %% [markdown]
# Depth or the height of the most selling diamonds is closer to 62 mm in both the histograms.

# %%
# Using Matplotlib Histogram 

df['table'].hist()
# Out:
# <AxesSubplot:>

# %%
# Using Seaborn Histogram 

sns.histplot(data=df, x="table")

plt.show()

# %% [markdown]
# The flat facet portion of the diamond, which is measured in relation to the width of the diamond, appears to bt thr most selling ones with around 57 mm table.

# %%
# Using Matplotlib Histogram 

df['x'].hist()
# Out:
# <AxesSubplot:>

# %%
# Using Seaborn Histogram 

sns.histplot(data=df, x="x")

plt.show()

# %% [markdown]
# "X" represents the length of the diamond. And the histogram shows that around 4.5 mm is the maximum selling length of diamond.

# %%
# Using Matplotlib Histogram 

df['y'].hist()
# Out:
# <AxesSubplot:>

# %%
# Using Seaborn Histogram 

sns.histplot(data=df, x="y")

plt.show()

# %% [markdown]
# "Y" represents the width of the diamond in mm. The highest selling diamond falls around 7 mm as per the histogram above.

# %%
# Using Matplotlib Histogram 

df['z'].hist()
# Out:
# <AxesSubplot:>

# %%
# Using Seaborn Histogram 

sns.histplot(data=df, x="z")

plt.show()

# %% [markdown]
# The diamonds that sell the most in quantity has the depth of around 5 mm.

# %%
# Using Seaborn Histogram 

sns.histplot(data=df, x="price")

plt.show()

# %% [markdown]
# Since histogram with Mathplot is giving error, price are represented only on seaborn histogram. It appears that the highest selling diamonds price ranges around $900.00

# %% [markdown]
# - > <h4>Using bar plot from Matplotlib library to provide graphical representation of categorical data such as cut, color and clarity as follows:</h4>

# %%
bplt = df['cut'].value_counts().plot.bar(title = "Freq Dist of Cut")
bplt
# Out:
# <AxesSubplot:title={'center':'Freq Dist of Cut'}>

# %% [markdown]
# It appears from the bar diagram that the diamond "ideal cut" sells the most.

# %%
bplt = df['color'].value_counts().plot.bar(title = "Freq Dist of Color")
bplt
# Out:
# <AxesSubplot:title={'center':'Freq Dist of Color'}>

# %% [markdown]
# "G" quality diamond color appears to sell the most as per the diagram.

# %%
bplt = df['clarity'].value_counts().plot.bar(title = "Freq Dist of Clarity")
bplt
# Out:
# <AxesSubplot:title={'center':'Freq Dist of Clarity'}>

# %% [markdown]
# "SI1" is known as slightly included which is the second to the least clear diamond to appear. Which sells the most. Lowest selling ones are the imperfect ones. "IF" which is the finest quality is the second least selling ones.

# %%
df.corr()

df.corr().hist()
# Out:
# array([[<AxesSubplot:title={'center':'Unnamed: 0'}>,
#         <AxesSubplot:title={'center':'carat'}>,
#         <AxesSubplot:title={'center':'depth'}>],
#        [<AxesSubplot:title={'center':'table'}>,
#         <AxesSubplot:title={'center':'price'}>,
#         <AxesSubplot:title={'center':'x'}>],
#        [<AxesSubplot:title={'center':'y'}>,
#         <AxesSubplot:title={'center':'z'}>, <AxesSubplot:>]], dtype=object)

# %% [markdown]
# <h3> Part 3: Inferences: </h3>

# %% [markdown]
# <h4> 1. What proportion of diamonds are between .30 and 1.08 carats?</h4>

# %%
#diamonds that are greater than 0.30 carat and less than 1.08 carats

df.loc[(df['carat'] > 0.30) & (df['carat'] < 1.08)]
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 13             14   0.31      Ideal     J     SI2   62.2   54.0    344  4.35
# 15             16   0.32    Premium     E      I1   60.9   58.0    345  4.38
# 23             24   0.31  Very Good     J     SI1   59.4   62.0    353  4.39
# 24             25   0.31  Very Good     J     SI1   58.1   62.0    353  4.44
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 4      4.35  2.75
# ...

# %%
(df.loc[(df['carat'] > .30) & (df['carat'] < 1.08)]).shape
# Out:
# (37431, 11)

# %% [markdown]
# There are 37431 different diamonds that are between 0.30 and 1.08 carat.

# %% [markdown]
# <h4> 2. How many of the diamonds have equal x and y dimensions? </h4>

# %%
# diamonds with x and y equal dimentions
df.loc[df['x'] == df['y']]
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 3397         3398   0.30      Ideal     H    VVS2   62.5   54.0    567  4.30
# 10055       10056   0.27  Very Good     F    VVS1   62.0   55.0    591  4.16
# 16516       16517   1.00    Premium     E     VS2   60.0   60.0   6600  6.43
# 16851       16852   1.00    Premium     E     VS2   60.0   60.0   6720  6.43
# 17368       17369   1.22    Premium     G     SI2   62.4   61.0   6969  6.79
# 34302       34303   0.32      Ideal     D    VVS2   62.1   54.0    858  4.40
# 40016       40017   0.42      Ideal     H    VVS1   62.8   57.0   1108  4.79
# 41855       41856   0.61    Premium     G     SI1   60.8   60.0   1255  5.42
# 42127       42128   0.48      Ideal     F     VS2   62.4   54.0   1279  5.03
# 43490       43491   0.51    Premium     F     SI1   61.4   59.0   1421  5.13
#
#           y     z
# 3397   4.30  2.70
# 10055  4.16  2.59
# 16516  6.43  3.89
# 16851  6.43  3.89
# 17368  6.79  4.23
# ...

# %% [markdown]
# There are 10 diamonds that have equal dimentions, after removing the ones with 0 values.

# %% [markdown]
# <h4> 3. How many of the diamonds have a carat value that is less than the mean carat value? </h4>

# %%
#carrat value less than mean carat value

df.loc[(df['carat'] < 0.797940)]
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53934       53935   0.72    Premium     D     SI1   62.7   59.0   2757  5.69
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %% [markdown]
# There are 31125 diamonds that fall under mean value carat.

# %% [markdown]
# <h4> 4. (4 Points) How many diamonds have a Premium cut or better? Note that the possible values for the quality of a
# cut are ranked in ascending order as follows: Fair / Good / Very Good / Premium / Ideal </h4>

# %%
df.loc[(df['cut'] == 'Premium') | (df['cut'] == 'Ideal')]
# Out:
#        Unnamed: 0  carat      cut color clarity  depth  table  price     x  \
# 0               1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21  Premium     E     SI1   59.8   61.0    326  3.89
# 3               4   0.29  Premium     I     VS2   62.4   58.0    334  4.20
# 11             12   0.23    Ideal     J     VS1   62.8   56.0    340  3.93
# 12             13   0.22  Premium     F     SI1   60.4   61.0    342  3.88
# ...           ...    ...      ...   ...     ...    ...    ...    ...   ...
# 53931       53932   0.71  Premium     F     SI1   59.8   62.0   2756  5.74
# 53934       53935   0.72  Premium     D     SI1   62.7   59.0   2757  5.69
# 53935       53936   0.72    Ideal     D     SI1   60.8   57.0   2757  5.75
# 53938       53939   0.86  Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75    Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# 1      3.84  2.31
# ...

# %% [markdown]
# There are 35339 diamonds that have a premium or better cut.

# %% [markdown]
# <h4> 5. Which diamond has the highest price per carat? What is its value? </h4>

# %%
# price_per_carat = np.array()
# df['price_per_carat'] = price_per_carat.tolist()
pd.options.mode.chained_assignment = None  # default='warn'

df = df[df['price'] / df['carat']]
df['price_per_carat']

# %% [markdown]
# <h4> 6. Using both Matplotlib and Seaborn, make boxplots of the diamond price for each distinct cut value and discuss any conclusions you can draw from the appearance of the boxplots. </h4>

# %%
sns.boxplot(data=df, y = 'price', x = 'cut')
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %% [markdown]
# <h4> 7. Using both Matplolib and Seaborn, make a scatter plot of price vs. carat. What can we say about the relationship between those two attributes? </h4>

# %%
plt.scatter( df['price'], df['carat'],)
plt.show()

# %%
sns.scatterplot(x='price',
                    y='carat',
                    data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='carat'>

# %% [markdown]
# The graph shows that the price and carat are directly related. Higher the carat, higher the price and vice versa.

# %% [markdown]
# <h3>Part 4: Conclusion: </h3>

# %% [markdown]
# It was important to understand different attributes used in this dataset. So, I did brief research on diamonds. I have tried to explain the attributes to the best of my knowledge.
#
# After looking at the summary of the data in the beginning, it gave me a general understanding of the data.
# The data provided looked clean, however there we some missing values in x, y, and z. And some had zero values. My approach was to remove some of those rows that had zero value, and I also provided a median value to a numerical data missing on "x". The next task was for me to find any outliers, which I found after careful analysis of the data. Some of the values in "y and "z" were well above other values and I decided to remove them from the dataset. Next was to analyse different attributes with the use of histogram for numerical dats and with the bar diagram for the categorical data.
#
# Most of the findings have been consistent, where the "four C's (carat, cut, color and clarity)" impacted the number of sales of a diamond. These 4 factors would impact the volume of the sales, better the quality, the sales were relatively less. The medium range quality at most part was sold in higher volume.
#
# When it comes to price and carat correlation, mostly the higher carat diamonds cost higher and vice versa.

# %% [markdown]
# References:
#
#
# Cornell Virtual Workshop, https://cvw.cac.cornell.edu/usecases/quality
#
# Tiffany & Co. https://www.tiffany.com/engagement/the-tiffany-guide-to-diamonds/clarity/
#
# Notes from professor
